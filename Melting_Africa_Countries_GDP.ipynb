# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
raw_csv = pd.read_excel("African_Countries_GDP.xlsx")

# %%
df=raw_csv.copy()

# %%
df.head()
# Out:
#         Country          1960          1961          1962          1963  \
# 0       Algeria  2.723593e+09  2.434727e+09  2.001428e+09  2.702960e+09
# 1        Angola  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2         Benin  2.261956e+08  2.356682e+08  2.364349e+08  2.539276e+08
# 3      Botswana  3.041231e+07  3.290234e+07  3.564321e+07  3.809115e+07
# 4  Burkina Faso  3.304428e+08  3.502472e+08  3.795670e+08  3.940406e+08
#
#            1964          1965          1966          1967          1968  ...  \
# 0  2.909293e+09  3.136259e+09  3.039835e+09  3.370843e+09  3.852116e+09  ...
# 1  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  ...
# 2  2.698190e+08  2.899087e+08  3.029253e+08  3.062220e+08  3.263231e+08  ...
# 3  4.161397e+07  4.579087e+07  5.146444e+07  5.864644e+07  6.624826e+07  ...
# 4  4.103216e+08  4.229168e+08  4.338898e+08  4.507540e+08  4.604427e+08  ...
#
# ...

# %%
df.melt(id_vars=["Country"],var_name="Year",value_name="GDP")
# Out:
#            Country  Year           GDP
# 0          Algeria  1960  2.723593e+09
# 1           Angola  1960  0.000000e+00
# 2            Benin  1960  2.261956e+08
# 3         Botswana  1960  3.041231e+07
# 4     Burkina Faso  1960  3.304428e+08
# ...            ...   ...           ...
# 3343          Togo  2021  0.000000e+00
# 3344       Tunisia  2021  0.000000e+00
# 3345        Uganda  2021  0.000000e+00
# 3346        Zambia  2021  0.000000e+00
# 3347      Zimbabwe  2021  0.000000e+00
#
# [3348 rows x 3 columns]

# %%
df.head()
# Out:
#         Country          1960          1961          1962          1963  \
# 0       Algeria  2.723593e+09  2.434727e+09  2.001428e+09  2.702960e+09
# 1        Angola  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2         Benin  2.261956e+08  2.356682e+08  2.364349e+08  2.539276e+08
# 3      Botswana  3.041231e+07  3.290234e+07  3.564321e+07  3.809115e+07
# 4  Burkina Faso  3.304428e+08  3.502472e+08  3.795670e+08  3.940406e+08
#
#            1964          1965          1966          1967          1968  ...  \
# 0  2.909293e+09  3.136259e+09  3.039835e+09  3.370843e+09  3.852116e+09  ...
# 1  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  ...
# 2  2.698190e+08  2.899087e+08  3.029253e+08  3.062220e+08  3.263231e+08  ...
# 3  4.161397e+07  4.579087e+07  5.146444e+07  5.864644e+07  6.624826e+07  ...
# 4  4.103216e+08  4.229168e+08  4.338898e+08  4.507540e+08  4.604427e+08  ...
#
# ...

# %%
df = df.drop(2021,axis=1)

# %% [markdown]
# Use df.melf as directed by this stack overflow post
# https://stackoverflow.com/questions/28654047/convert-columns-into-rows-with-pandas

# %%
df_melted = df.melt(id_vars=["Country"],var_name="Year",value_name="GDP")

# %%
df_melted
# Out:
#            Country  Year           GDP
# 0          Algeria  1960  2.723593e+09
# 1           Angola  1960  0.000000e+00
# 2            Benin  1960  2.261956e+08
# 3         Botswana  1960  3.041231e+07
# 4     Burkina Faso  1960  3.304428e+08
# ...            ...   ...           ...
# 3289          Togo  2020  7.574637e+09
# 3290       Tunisia  2020  4.162035e+10
# 3291        Uganda  2020  3.760037e+10
# 3292        Zambia  2020  1.811063e+10
# 3293      Zimbabwe  2020  1.805117e+10
#
# [3294 rows x 3 columns]

# %%
df_melted=df_melted.sort_values(["Country","Year"])

# %%
df_melted.to_excel("Melted_African_Countries_GDP.xlsx")
