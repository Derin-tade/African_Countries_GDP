# %%
import pandas as pd
import numpy as np

# %%
raw_csv = pd.read_excel("Countries_GDP.xlsx")

# %%
df = raw_csv.copy()

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  1.931311e+10  1.972349e+10  2.149392e+10  2.573321e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.040428e+10  1.112805e+10  1.194335e+10  1.267652e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2012          2013          2014  \
# ...

# %%
African_Countries= ["Algeria","Angola","Benin", 'Botswana',"Burkina Faso", "Burundi","Cameroon", "Cabo Verde", "Central African Republic", "Chad","Comoros", "Congo, Dem. Rep.", "Congo, Rep.", "Cote d'Ivoire","Djibouti","Egypt, Arab Rep.", "Equatorial Guinea", "Eritrea", "Eswatini","Ethiopia", "Gabon", "Gambia, The","Ghana","Guinea", "Guinea-Bissau","Kenya","Lesotho", "Liberia", "Libya","Madagascar", "Malawi","Mali","Mauritania", "Mauritius","Morocco", "Mozambique","Namibia", "Niger", "Nigeria","Rwanda","Sao Tome and Principe","Senegal", "Seychelles", "Sierra Leone","Somalia", "South Africa", "Sudan","South Sudan","Tanzania", "Togo","Tunisia","Uganda","Zambia", "Zimbabwe"]

# %%
len(African_Countries)
# Out:
# 54

# %%
df_African_Countries = df.loc[African_Countries,:]

# %%
df_African_Countries.head()
# Out:
#              Country Code     Indicator Name  Indicator Code          1960  \
# Country Name
# Algeria               DZA  GDP (current US$)  NY.GDP.MKTP.CD  2.723593e+09
# Angola                AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# Benin                 BEN  GDP (current US$)  NY.GDP.MKTP.CD  2.261956e+08
# Botswana              BWA  GDP (current US$)  NY.GDP.MKTP.CD  3.041231e+07
# Burkina Faso          BFA  GDP (current US$)  NY.GDP.MKTP.CD  3.304428e+08
#
#                       1961          1962          1963          1964  \
# Country Name
# Algeria       2.434727e+09  2.001428e+09  2.702960e+09  2.909293e+09
# Angola                 NaN           NaN           NaN           NaN
# Benin         2.356682e+08  2.364349e+08  2.539276e+08  2.698190e+08
# Botswana      3.290234e+07  3.564321e+07  3.809115e+07  4.161397e+07
# Burkina Faso  3.502472e+08  3.795670e+08  3.940406e+08  4.103216e+08
#
# ...

# %%
df_African_Countries.drop(["Indicator Name","Indicator Code","Country Code"],axis=1)
# Out:
#                                   1960          1961          1962  \
# Country Name
# Algeria                   2.723593e+09  2.434727e+09  2.001428e+09
# Angola                             NaN           NaN           NaN
# Benin                     2.261956e+08  2.356682e+08  2.364349e+08
# Botswana                  3.041231e+07  3.290234e+07  3.564321e+07
# Burkina Faso              3.304428e+08  3.502472e+08  3.795670e+08
# Burundi                   1.960000e+08  2.030000e+08  2.135000e+08
# Cameroon                  6.142061e+08  6.527776e+08  6.942477e+08
# Cabo Verde                         NaN           NaN           NaN
# Central African Republic  1.121556e+08  1.231346e+08  1.244827e+08
# Chad                      3.135827e+08  3.339753e+08  3.576357e+08
# Comoros                            NaN           NaN           NaN
# Congo, Dem. Rep.          3.359404e+09  3.086747e+09  3.779841e+09
# Congo, Rep.               1.317319e+08  1.516757e+08  1.665212e+08
# ...

# %%
df_African_Countries.fillna(0)
# Out:
#                          Country Code     Indicator Name  Indicator Code  \
# Country Name
# Algeria                           DZA  GDP (current US$)  NY.GDP.MKTP.CD
# Angola                            AGO  GDP (current US$)  NY.GDP.MKTP.CD
# Benin                             BEN  GDP (current US$)  NY.GDP.MKTP.CD
# Botswana                          BWA  GDP (current US$)  NY.GDP.MKTP.CD
# Burkina Faso                      BFA  GDP (current US$)  NY.GDP.MKTP.CD
# Burundi                           BDI  GDP (current US$)  NY.GDP.MKTP.CD
# Cameroon                          CMR  GDP (current US$)  NY.GDP.MKTP.CD
# Cabo Verde                        CPV  GDP (current US$)  NY.GDP.MKTP.CD
# Central African Republic          CAF  GDP (current US$)  NY.GDP.MKTP.CD
# Chad                              TCD  GDP (current US$)  NY.GDP.MKTP.CD
# Comoros                           COM  GDP (current US$)  NY.GDP.MKTP.CD
# Congo, Dem. Rep.                  COD  GDP (current US$)  NY.GDP.MKTP.CD
# ...

# %%
df_African_Countries=df_African_Countries.drop(["Indicator Name","Indicator Code","Country Code"],axis=1)

# %%
df_African_Countries.to_csv("African_Countries_GDP.csv")
